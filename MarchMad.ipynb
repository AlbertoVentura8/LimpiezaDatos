# %% [markdown]
# <a href="https://colab.research.google.com/github/AlbertoVentura8/LimpiezaDatos/blob/main/MarchMad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Hacemos la carga del dataset. Dataset previamente subido a GoogleColab.
import pandas as pd
MarchMad = pd.read_csv("/content/DEV _ March Madness.csv")
print("Tamaño del dataset:", MarchMad.shape)
MarchMad.head()
# Out:
# Tamaño del dataset: (7950, 144)
#    Season Team Name                       Conference  \
# 0    2015  Kentucky    Southeastern Conference (SEC)
# 1    2021   Gonzaga      West Coast Conference (WCC)
# 2    2024     UConn              Big East Conference
# 3    2008    Kansas                Big 12 Conference
# 4    2019  Virginia  Atlantic Coast Conference (ACC)
#
#              Historical Conference  Adjusted Temo  Adjusted Tempo Rank  \
# 0    Southeastern Conference (SEC)           62.4                  274
# 1      West Coast Conference (WCC)           73.8                    7
# 2              Big East Conference           64.6                  330
# 3                Big 12 Conference           66.8                  109
# 4  Atlantic Coast Conference (ACC)           59.4                  353
#
#    Raw Tempo  Raw Tempo Rank  Adjusted Offensive Efficiency  \
# 0       63.8             242                          121.3
# ...

# %%
#En esta línea eliminamos todas la columnas que tengan la palabra Raw, para reducir el dataset inicial.
MarchMad = MarchMad.loc[:, ~MarchMad.columns.str.contains('Raw')]
print("Tamaño del dataset:", MarchMad.shape)
MarchMad.head()
# Out:
# Tamaño del dataset: (7950, 138)
#    Season Team Name                       Conference  \
# 0    2015  Kentucky    Southeastern Conference (SEC)
# 1    2021   Gonzaga      West Coast Conference (WCC)
# 2    2024     UConn              Big East Conference
# 3    2008    Kansas                Big 12 Conference
# 4    2019  Virginia  Atlantic Coast Conference (ACC)
#
#              Historical Conference  Adjusted Temo  Adjusted Tempo Rank  \
# 0    Southeastern Conference (SEC)           62.4                  274
# 1      West Coast Conference (WCC)           73.8                    7
# 2              Big East Conference           64.6                  330
# 3                Big 12 Conference           66.8                  109
# 4  Atlantic Coast Conference (ACC)           59.4                  353
#
#    Adjusted Offensive Efficiency  Adjusted Offensive Efficiency Rank  \
# 0                          121.3                                   6
# ...

# %%
#Hacemos lo mismo que en la línea anterior para eliminar los rankings.
MarchMad = MarchMad.loc[:, ~MarchMad.columns.str.contains('Rank')]
print("Tamaño del dataset:", MarchMad.shape)
MarchMad.head()
# Out:
# Tamaño del dataset: (7950, 75)
#    Season Team Name                       Conference  \
# 0    2015  Kentucky    Southeastern Conference (SEC)
# 1    2021   Gonzaga      West Coast Conference (WCC)
# 2    2024     UConn              Big East Conference
# 3    2008    Kansas                Big 12 Conference
# 4    2019  Virginia  Atlantic Coast Conference (ACC)
#
#              Historical Conference  Adjusted Temo  \
# 0    Southeastern Conference (SEC)           62.4
# 1      West Coast Conference (WCC)           73.8
# 2              Big East Conference           64.6
# 3                Big 12 Conference           66.8
# 4  Atlantic Coast Conference (ACC)           59.4
#
#    Adjusted Offensive Efficiency  Adjusted Defensive Efficiency  \
# 0                          121.3                           84.4
# 1                          126.4                           89.9
# 2                          127.5                           91.1
# ...

# %%
# Con estas dos limpiezas, ya hemos pasado de un dataset de 144 columnas, a uno más manejable de 75
# Vamos a ver los tipos de nuestras columnas
print(MarchMad.dtypes)
tipo_resumen = MarchMad.dtypes.value_counts()
print("Tipos de Datos más comunes: ", tipo_resumen)
# Out:
# Season                                    int64
# Team Name                                object
# Conference                               object
# Historical Conference                    object
# Adjusted Temo                           float64
#                                          ...
# Net Rating                              float64
# Seed                                     object
# Region                                   object
# Post-Season Tournament                   object
# Post-Season Tournament Sorting Index      int64
# Length: 75, dtype: object
# Tipos de Datos más comunes:  float64    65
# object      8
# int64       2
# Name: count, dtype: int64

# %%
# Vamos a ver que variedad de años tenemos, para quedarnos con los últimos años
MarchMad['Season'].value_counts()
# Out:
# Season
# 2023    363
# 2024    362
# 2022    358
# 2021    357
# 2019    353
# 2020    353
# 2015    351
# 2017    351
# 2018    351
# 2014    351
# 2016    351
# 2010    347
# 2013    347
# 2012    345
# 2011    345
# 2009    344
# 2008    341
# 2007    336
# 2006    334
# 2005    330
# 2002    327
# 2003    327
# 2004    326
# Name: count, dtype: int64

# %%
#Como vemos todos los años están bastante parecidos, y tenemos datos desde el 2002. Vamos a eliminar los datos del 2002, 2003 y 2004 para reducir algo mas el dataset y usar los últimos 20 años
MarchMad = MarchMad[~MarchMad['Season'].isin([2002, 2003, 2004])]
MarchMad['Season'].value_counts()
# Out:
# Season
# 2023    363
# 2024    362
# 2022    358
# 2021    357
# 2019    353
# 2020    353
# 2015    351
# 2018    351
# 2014    351
# 2017    351
# 2016    351
# 2010    347
# 2013    347
# 2012    345
# 2011    345
# 2009    344
# 2008    341
# 2007    336
# 2006    334
# 2005    330
# Name: count, dtype: int64

# %%
# Vamos a ver el número de líneas que nos quedan
print("Tamaño del dataset:", MarchMad.shape)
# Out:
# Tamaño del dataset: (6970, 75)

# %%
# Vamos a eliminar todas las lineas que tengan algún tipo de caracter en blanco
MarchMad = MarchMad.replace(pd.NA, regex=True).dropna()
print("Tamaño del dataset:", MarchMad.shape)
MarchMad.head()
# Out:
# Tamaño del dataset: (6966, 75)
#    Season   Team Name                       Conference  \
# 4    2019    Virginia  Atlantic Coast Conference (ACC)
# 6    2021      Baylor                Big 12 Conference
# 7    2015   Wisconsin      Big Ten Conference (Big 10)
# 8    2018   Villanova              Big East Conference
# 9    2011  Ohio State      Big Ten Conference (Big 10)
#
#              Historical Conference  Adjusted Temo  \
# 4  Atlantic Coast Conference (ACC)           59.4
# 6                Big 12 Conference           67.4
# 7      Big Ten Conference (Big 10)           58.7
# 8              Big East Conference           68.7
# 9      Big Ten Conference (Big 10)           63.8
#
#    Adjusted Offensive Efficiency  Adjusted Defensive Efficiency  \
# 4                          123.4                           89.2
# 6                          125.0                           91.1
# 7                          129.0                           95.2
# ...
